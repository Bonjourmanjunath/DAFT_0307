# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries


import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math
import seaborn as sns

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

plt.plot(x,y)

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1


# plt.plot(x,y) 
plt.plot(x,z)

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# # Method 2
# fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, sharey=True, figsize=(15,5))

# ax1.set_title("Example Line Chart")
# ax1.set_xlabel("X")
# ax1.set_ylabel("Y")
# ax1.set_zlabel("Z")
# ax1.plot(x,y)
# ax1.plot(x,z)

# ax2.set(title="Example Bar Chart X_Y", xlabel="X", ylabel="Y")
# ax2.bar(x,y)

# ax3.set(title="Example Bar Chart X_Z", xlabel="X", zlabel="Z")
# ax3.bar(x,z)

# plt.show()




# # Given data
# x = np.arange(0, 100)
# y = x * 2
# z = x ** 2

# Create a figure with two subplots
fig, (axes1, axes2) = plt.subplots(1, 2, figsize=(12, 6))


axes1.plot(x, y, label='y = 2x')
axes1.set_title('Example Bar Chart X_Y')
axes1.set_xlabel('x')
axes1.set_ylabel('y')
axes1.legend()


axes2.plot(x, z, label='z = x^2')
axes2.set_title('Example Bar Chart X_Z')
axes2.set_xlabel('x')
axes2.set_ylabel('z')
axes2.legend()

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here
axes1.set_title('Example Bar Chart X_Y')
axes2.set_title('Example Bar Chart X_Z')
# Out:
# Text(0.5, 1.0, 'Example Bar Chart X_Z')

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
# fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# ax1.plot(x, y1, label='y1 = x^2')
# ax1.plot(x, y2, label='y2 = e^x')
# ax1.set_title('Normal Scale')
# ax1.set_xlabel('y1')
# ax1.set_ylabel('y2')
# ax1.legend()

# ax2.plot(x, y1, label='y1 = x^2')
# ax2.plot(x, y2, label='y2 = e^x')
# ax2.set_title('Logarithmic Scale')
# ax2.set_xlabel('y1')
# ax2.set_ylabel('y2')
# ax2.set_xscale('log')
# ax2.set_yscale('log')
# ax2.legend()

# # Step 7: Show the plot
# plt.tight_layout()
# plt.show()

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here


import pandas as pd


df1 = pd.read_csv("fitbit2.csv")
df2 = pd.read_csv("titanic.csv")

df1.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# # MEDIAN STEPS BY MONTH_ENCODED
# # your code here

sns.boxplot(data=df1, x="Months_encoded", y="Steps") # ci=None
plt.show()

# f, ax = plt.subplots(figsize=(15,6))
# ax = sns.boxplot(data=Months_encoded, x='Steps', y='Months')
# # for patch in ax.artists:
# #     patch.set_alpha(0.3)
# # sns.stripplot(data=penguins, x='species', y='body_mass_g', alpha=0.5, size=9)
# plt.show()

# # MEDIAN STEPS BY WORK_OR_WEEKEND
# # your code here

sns.boxplot(data=df1, x="Work_or_Weekend", y="Steps") # ci=None
plt.show()

sns.regplot(data=df1[df1['species'] == 'Gentoo'], x='bill_length_mm', y='bill_depth_mm')
plt.show()

# import pandas as pd
# import matplotlib.pyplot as plt

# # Assuming you have loaded the Fitbit data into a DataFrame called "fitbit_data"
# # Adjust the column names as per your actual data

# %%
df1 = pd.read_csv("fitbit2.csv")

df1
# Out:
#            Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0    2015-05-08            1934    905      0.65       0              1.355
# 1    2015-05-09            3631  18925     14.11       4            611.000
# 2    2015-05-10            3204  14228     10.57       1            602.000
# 3    2015-05-11            2673   6756      5.02       8            749.000
# 4    2015-05-12            2495    502      3.73       1            876.000
# ..          ...             ...    ...       ...     ...                ...
# 362  2016-05-03            3796  18588     14.13      16            599.000
# 363  2016-05-04            3525  16382     12.39      16            684.000
# 364  2016-05-05            3649  21913     16.40      19            701.000
# 365  2016-05-06            3539  19023     14.79      15            575.000
# 366  2016-05-07             304   9526      7.08       2            564.000
#
# ...

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here

import matplotlib.pyplot as plt

# Features to plot
features = ['Minutes Lightly Active', 'Minutes Very Active', 'Minutes Sedentary']

# Create a scatter plot for each feature
for feature in features:
    plt.figure(figsize=(8, 6))
    plt.scatter(df1[feature], df1['Steps'], alpha=1)
    plt.xlabel(feature)
    plt.ylabel('Steps')
    plt.title(f'Scatter Plot: {feature} vs. Steps')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code her
df2 = pd.read_csv("titanic.csv")
df2
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name  Gender        Age  \
# 0                               Braund, Mr. Owen Harris    male  22.000000
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                                Heikkinen, Miss. Laina  female  26.000000
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                              Allen, Mr. William Henry    male  35.000000
# ...

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here

df2 = pd.read_csv("titanic.csv")
numerical_variables = df2.select_dtypes(include=['int', 'float'])


categorical_variables = df2.select_dtypes(include=['object','category'])

numerical_variables
#
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
# CATEGORICAL VARIABLES
# your code here
categorical_variables
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here


sns.pairplot(data=df2, hue="Gender")
plt.plot()

# %%
pd.plotting.scatter_matrix(df2, figsize=(12,26), hist_kwds={"bins":10})
plt.plot()
# Out:
# []

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here


# sns.lineplot(data=df2, x="Gender", y="Age")
# plt.show()

# sns.lineplot(data=df2, x="Pclass", y="Age")



plt.hist(df2['Age'], bins=10)
plt.show()

# %%
sns.heatmap(df2.corr(), annot=True)
# Out:
# /var/folders/18/4d713mgd2bv29dm1dhff_k440000gn/T/ipykernel_49409/1738403036.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df2.corr(), annot=True)
# <Axes: >

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here

# plt.hist(df2['Age'], bins=10,20,50 edgecolor='black')
# plt.show()


fig, axs = plt.subplots(1, 3, figsize=(15, 5))


axs[0].hist(df2['Age'], bins=10)
axs[0].set_title('Distribution with 10 Bins')
axs[0].set_xlabel('Age')
axs[0].set_ylabel('Frequency')


axs[1].hist(df2['Age'], bins=20)
axs[1].set_title('Distribution with 20 Bins')
axs[1].set_xlabel('Age')
axs[1].set_ylabel('Frequency')


axs[2].hist(df2['Age'], bins=50)
axs[2].set_title('Distribution with 50 Bins')
axs[2].set_xlabel('Age')
axs[2].set_ylabel('Frequency')

# Adjust layout to prevent overlapping of titles and labels
plt.tight_layout()

# Display the plots
plt.show()

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here
# sns.scatterplot(data=df2, x="bill_length_mm", y="bill_depth_mm", hue="species", alpha=0.7)
# plt.show()



sns.histplot(data=df2, x='Age', bins=20)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Distribution of Age (Histogram)')
plt.show()

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

sns.histplot(data=df2, x='Gender', bins=20)
plt.xlabel('Gender')
plt.ylabel('Frequency')
plt.title('Distribution of Gender (Histogram)')
plt.show()

# %%
sns.pairplot(data=df2, hue="Gender")

# %%
# Method 2 - seaborn
# your code here

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here

sns.pairplot(data=df2, hue="Pclass")

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here



sns.boxplot(data=df2, y='Age')
plt.ylabel('Age')
plt.title('Summary Statistics of Age')
plt.show()

# %%
"""
your comments here
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

sns.histplot(data=df2, x='Age', bins=20)
plt.xlabel('Age')

plt.title('Distribution of Age (Histogram)')
plt.show()

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here


sns.regplot(data=df2, x='Age', y='Fare')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.title('Regression Plot of Fare vs. Age')
plt.show()

# %%
# Method 2 - seaborn
# your code here

sns.regplot(data=df2, x='Age', y='Fare')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.title('Regression Plot of Fare vs. Age')
plt.show()

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here


sns.regplot(data=df2,x='Age' , y = 'Pclass')
plt.xlabel('Age')
plt.ylabel('Pclass')
plt.title (' statistics of Age depending on Pclass')
plt.show()


sns.scatterplot(data=df2, x="Age", y="Pclass")
plt.show()

f, ax = plt.subplots(figsize=(15,6))
ax = sns.boxplot(data=df2, x='Pclass', y='Age')
plt.show()

# %%
f, ax = plt.subplots(figsize=(30,10))
ax = sns.boxplot(data=df2, x='Pclass', y='Age')
plt.show()

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
