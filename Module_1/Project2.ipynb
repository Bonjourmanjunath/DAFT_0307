# %%
import pandas as pd
import matplotlib.pyplot as plt
import wbgapi as wb

# %%
wb.series.info(q="underweight")
# Out:
# id                 value
# -----------------  -------------------------------------------------------------------------
# SH.STA.MALN.FE.ZS  Prevalence of underweight, weight for age, female (% of children under 5)
# SH.STA.MALN.MA.ZS  Prevalence of underweight, weight for age, male (% of children under 5)
# SH.STA.MALN.ZS     Prevalence of underweight, weight for age (% of children under 5)
#                    3 elements

# %%
HepB3 = wb.data.DataFrame('SH.IMM.HEPB', wb.region.members('SAS'))
HepB3
# Out:
#          YR1960  YR1961  YR1962  YR1963  YR1964  YR1965  YR1966  YR1967  \
# economy
# AFG         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# BGD         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# BTN         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# IND         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# LKA         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# MDV         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# NPL         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# PAK         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#          YR1968  YR1969  ...  YR2013  YR2014  YR2015  YR2016  YR2017  YR2018  \
# economy                  ...
# AFG         NaN     NaN  ...    64.0    62.0    64.0    66.0    66.0    72.0
# BGD         NaN     NaN  ...    96.0    97.0    98.0    98.0    98.0    98.0
# ...

# %%
Immunization_measles  = wb.data.DataFrame('SH.IMM.MEAS', wb.region.members('SAS'))
Immunization_measles
# Out:
#          YR1960  YR1961  YR1962  YR1963  YR1964  YR1965  YR1966  YR1967  \
# economy
# AFG         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# BGD         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# BTN         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# IND         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# LKA         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# MDV         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# NPL         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# PAK         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#          YR1968  YR1969  ...  YR2013  YR2014  YR2015  YR2016  YR2017  YR2018  \
# economy                  ...
# AFG         NaN     NaN  ...    57.0    60.0    62.0    64.0    67.0    71.0
# BGD         NaN     NaN  ...    91.0    94.0    97.0    97.0    97.0    97.0
# ...

# %%
Immunization_DPT  = wb.data.DataFrame('SH.IMM.MEAS', wb.region.members('SAS'))
Immunization_DPT
# Out:
#          YR1960  YR1961  YR1962  YR1963  YR1964  YR1965  YR1966  YR1967  \
# economy
# AFG         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# BGD         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# BTN         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# IND         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# LKA         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# MDV         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# NPL         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# PAK         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#          YR1968  YR1969  ...  YR2013  YR2014  YR2015  YR2016  YR2017  YR2018  \
# economy                  ...
# AFG         NaN     NaN  ...    57.0    60.0    62.0    64.0    67.0    71.0
# BGD         NaN     NaN  ...    91.0    94.0    97.0    97.0    97.0    97.0
# ...

# %%
underweight = wb.data.DataFrame('SH.STA.MALN.ZS', wb.region.members('SAS'))
underweight
# Out:
#          YR1960  YR1961  YR1962  YR1963  YR1964  YR1965  YR1966  YR1967  \
# economy
# AFG         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# BGD         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# BTN         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# IND         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# LKA         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# MDV         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# NPL         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# PAK         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#          YR1968  YR1969  ...  YR2013  YR2014  YR2015  YR2016  YR2017  YR2018  \
# economy                  ...
# AFG         NaN     NaN  ...    24.6     NaN     NaN     NaN     NaN    19.1
# BGD         NaN     NaN  ...    31.9    32.8    28.9     NaN     NaN    21.9
# ...

# %%
gov_health_expenditure = wb.data.DataFrame('SH.XPD.GHED.GD.ZS', wb.region.members('SAS'))
gov_health_expenditure
# Out:
#          YR1960  YR1961  YR1962  YR1963  YR1964  YR1965  YR1966  YR1967  \
# economy
# AFG         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# BGD         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# BTN         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# IND         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# LKA         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# MDV         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# NPL         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# PAK         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#          YR1968  YR1969  ...    YR2013    YR2014    YR2015    YR2016  \
# economy                  ...
# AFG         NaN     NaN  ...  0.443359  0.472657  0.522673  0.600130
# BGD         NaN     NaN  ...  0.523801  0.505570  0.465327  0.569685
# BTN         NaN     NaN  ...  2.554128  2.455318  2.789641  2.644663
# ...

# %%
UHC_Score = wb.data.DataFrame('SH.UHC.SRVS.CV.XD', wb.region.members('SAS'))
UHC_Score
# Out:
#          YR1960  YR1961  YR1962  YR1963  YR1964  YR1965  YR1966  YR1967  \
# economy
# AFG         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# BGD         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# BTN         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# IND         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# LKA         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# MDV         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# NPL         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# PAK         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#          YR1968  YR1969  ...  YR2013  YR2014  YR2015  YR2016  YR2017  YR2018  \
# economy                  ...
# AFG         NaN     NaN  ...     NaN     NaN    36.0     NaN    41.0     NaN
# BGD         NaN     NaN  ...     NaN     NaN    45.0     NaN    48.0     NaN
# ...

# %%
physician = wb.data.DataFrame('SH.MED.PHYS.ZS', wb.region.members('SAS'))
physician
# Out:
#          YR1960  YR1961  YR1962  YR1963  YR1964  YR1965  YR1966  YR1967  \
# economy
# AFG       0.035     NaN     NaN     NaN     NaN   0.063     NaN     NaN
# BGD         NaN     NaN     NaN     NaN     NaN   0.123     NaN     NaN
# BTN         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# IND       0.210     NaN     NaN     NaN     NaN   0.205     NaN     NaN
# LKA       0.223     NaN     NaN     NaN     NaN   0.172     NaN     NaN
# MDV         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# NPL       0.013     NaN     NaN     NaN     NaN   0.021     NaN     NaN
# PAK       0.185     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#          YR1968  YR1969  ...  YR2013  YR2014  YR2015  YR2016  YR2017  YR2018  \
# economy                  ...
# AFG         NaN     NaN  ...  0.2846  0.2983  0.2850  0.2782  0.2409  0.2966
# BGD         NaN     NaN  ...  0.4218  0.4887  0.4858  0.4974  0.5433  0.5809
# ...

# %%
nurse = wb.data.DataFrame('SH.MED.NUMW.P3', wb.region.members('SAS'))
nurse
# Out:
#          YR1960  YR1961  YR1962  YR1963  YR1964  YR1965  YR1966  YR1967  \
# economy
# AFG         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# BGD         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# BTN         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# IND         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# LKA         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# MDV         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# NPL         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# PAK         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#          YR1968  YR1969  ...  YR2013  YR2014  YR2015  YR2016  YR2017  YR2018  \
# economy                  ...
# AFG         NaN     NaN  ...  0.2495  0.1476  0.1299  0.1482  0.1755  0.4461
# BGD         NaN     NaN  ...  0.2100  0.2560  0.2750  0.2639  0.3163  0.3962
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine
import pymysql.cursors
import os
import getpass

# %%
pw = getpass.getpass()
# Out:
#  ········

# %%
connection_string = 'mysql+pymysql://root:' + pw + '@localhost:3306/'
engine = create_engine(connection_string)

# %%
sql = "create database medical_resources"

# %%
nurse = nurse.reset_index()

# %%
nurse.to_sql('nurse', engine, 'medical_resources', if_exists='replace', index=False)
# Out:
# 8

# %%
physician = physician.reset_index()

# %%
physician.to_sql('physician', engine, 'medical_resources', if_exists='replace', index=False)
# Out:
# 8

# %%
UHC_Score = UHC_Score.reset_index()

# %%
UHC_Score
# Out:
#    level_0  index economy  YR1960  YR1961  YR1962  YR1963  YR1964  YR1965  \
# 0        0      0     AFG     NaN     NaN     NaN     NaN     NaN     NaN
# 1        1      1     BGD     NaN     NaN     NaN     NaN     NaN     NaN
# 2        2      2     BTN     NaN     NaN     NaN     NaN     NaN     NaN
# 3        3      3     IND     NaN     NaN     NaN     NaN     NaN     NaN
# 4        4      4     LKA     NaN     NaN     NaN     NaN     NaN     NaN
# 5        5      5     MDV     NaN     NaN     NaN     NaN     NaN     NaN
# 6        6      6     NPL     NaN     NaN     NaN     NaN     NaN     NaN
# 7        7      7     PAK     NaN     NaN     NaN     NaN     NaN     NaN
#
#    YR1966  ...  YR2013  YR2014  YR2015  YR2016  YR2017  YR2018  YR2019  \
# 0     NaN  ...     NaN     NaN    36.0     NaN    41.0     NaN    42.0
# 1     NaN  ...     NaN     NaN    45.0     NaN    48.0     NaN    50.0
# 2     NaN  ...     NaN     NaN    53.0     NaN    56.0     NaN    60.0
# ...

# %%
UHC_Score.to_sql('UHC_Score', engine, 'medical_resources', if_exists='replace', index=False)
# Out:
# 8

# %%
gov_health_expenditure = gov_health_expenditure.reset_index()

# %%
gov_health_expenditure.to_sql('gov_health_expenditure', engine, 'medical_resources', if_exists='replace', index=False)
# Out:
# 8

# %%
underweight = underweight.reset_index()

# %%
underweight.to_sql('underweight', engine, 'medical_resources', if_exists='replace', index=False)
# Out:
# 8

# %%
HepB3
# Out:
#   economy  YR1960  YR1961  YR1962  YR1963  YR1964  YR1965  YR1966  YR1967  \
# 0     AFG     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1     BGD     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2     BTN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3     IND     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4     LKA     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 5     MDV     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 6     NPL     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 7     PAK     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#    YR1968  ...  YR2013  YR2014  YR2015  YR2016  YR2017  YR2018  YR2019  \
# 0     NaN  ...    64.0    62.0    64.0    66.0    66.0    72.0    72.0
# 1     NaN  ...    96.0    97.0    98.0    98.0    98.0    98.0    98.0
# 2     NaN  ...    97.0    99.0    99.0    98.0    98.0    97.0    97.0
# ...

# %%
HepB3 = HepB3.reset_index()

# %%
HepB3.to_sql('HepB3', engine, 'medical_resources', if_exists='replace', index=False)
# Out:
# 8

# %%
Immunization_DPT = Immunization_DPT.reset_index()

# %%
Immunization_DPT.to_sql('Immunization_DPT', engine, 'medical_resources', if_exists='replace', index=False)
# Out:
# 8
